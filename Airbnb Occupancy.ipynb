# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
combined=pd.read_csv("los.angeles.2019-12-05.listings.csv.gz")
combinedt=pd.read_csv("los.angeles.2019-01-11.listings.csv.gz")
# Out:
# C:\Users\Hayden\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (43,61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
conditions = [
    (combinedt['neighbourhood_cleansed'] == 'Long Beach') |
    (combinedt['neighbourhood_cleansed'] == 'Santa Monica') | 
    (combinedt['neighbourhood_cleansed'] == 'Mar Vista')]
values=['Coastal']
combinedt['Geographical']=np.select(conditions,values)
coastal=combinedt[combinedt['Geographical']=='Coastal']
coast=coastal.loc[:,['id','minimum_nights','Geographical']]
coast['minimum_nights'].value_counts().sort_index()
combinedtt=combinedt.loc[:,['id','minimum_nights','Geographical']]

# %%
conditions = [
    (combinedt['neighbourhood_cleansed'] == 'Glendale') |
    (combinedt['neighbourhood_cleansed'] == 'Pasadena') | 
    (combinedt['neighbourhood_cleansed'] == 'Sherman Oaks')|
(combinedt['neighbourhood_cleansed'] == 'Studio City')]
values=['Suburban']
combinedtt['Geographical']=np.select(conditions,values)
suburban=combinedtt[combinedtt['Geographical']=='Suburban']
suburbant=suburban.loc[:,['id','minimum_nights','Geographical']]
suburbant['minimum_nights'].value_counts().sort_index()
# Out:
# 1      728
# 2      566
# 3      297
# 4       59
# 5       74
# 6       13
# 7       72
# 8        3
# 9        1
# 10       8
# 13       1
# 14      20
# 15       8
# 16       1
# 18       1
# 19       1
# 20       7
# 21       3
# 22       1
# 25       2
# 26       1
# 28      10
# 29       1
# 30      82
# 31      40
# 32       1
# 34       1
# 35       1
# 38       1
# 39       2
# 40       1
# 45       2
# 50       1
# 60       4
# 90       3
# 94       1
# 99       1
# 100      2
# 150      1
# 180      3
# 360      1
# 365      1
# Name: minimum_nights, dtype: int64

# %%
conditions = [
    (combinedt['neighbourhood_cleansed'] == 'Hollywood') |
    (combinedt['neighbourhood_cleansed'] == 'Downtown') | 
    (combinedt['neighbourhood_cleansed'] == 'Echo Park') |
(combinedt['neighbourhood_cleansed'] == 'Silver Lake')]
values=['Downtown']
combinedt['Geographical']=np.select(conditions,values)
combinedt
downtown=combinedt[combinedt['Geographical']=='Downtown']
downtownt=downtown.loc[:,['id','minimum_nights','Geographical']]
downtownt['minimum_nights'].value_counts().sort_index()
# Out:
# 1      2919
# 2      1515
# 3       640
# 4       185
# 5       182
# 6        40
# 7       134
# 8         6
# 9         4
# 10       28
# 11        2
# 12        6
# 13        3
# 14       50
# 15       20
# 17        1
# 18        1
# 19        1
# 20        9
# 21        8
# 24        1
# 25        7
# 28       10
# 29       13
# 30      153
# 31       51
# 33        1
# 35        1
# 43        1
# 45        2
# 50        1
# 59        1
# 60        3
# 70        1
# 85        2
# 90        4
# 99        1
# 120       2
# 150       1
# 180       6
# 240       1
# 356       1
# 365       2
# 730       1
# Name: minimum_nights, dtype: int64

# %%
combined
# Out:
#              id                            listing_url       scrape_id  \
# 0           109       https://www.airbnb.com/rooms/109  20191205175409
# 1           344       https://www.airbnb.com/rooms/344  20191205175409
# 2          2708      https://www.airbnb.com/rooms/2708  20191205175409
# 3          2732      https://www.airbnb.com/rooms/2732  20191205175409
# 4          2864      https://www.airbnb.com/rooms/2864  20191205175409
# ...         ...                                    ...             ...
# 40120  40599772  https://www.airbnb.com/rooms/40599772  20191205175409
# 40121  40599853  https://www.airbnb.com/rooms/40599853  20191205175409
# 40122  40601503  https://www.airbnb.com/rooms/40601503  20191205175409
# 40123  40601789  https://www.airbnb.com/rooms/40601789  20191205175409
# 40124  40603848  https://www.airbnb.com/rooms/40603848  20191205175409
#
#       last_scraped                                               name  \
# ...

# %%
jan=pd.read_csv("los.angeles.2019-01-11.calendar.csv.gz")
feb=pd.read_csv("los.angeles.2019-02-03.calendar.csv.gz")
march=pd.read_csv("los.angeles.2019-03-06.calendar.csv.gz")
april=pd.read_csv("los.angeles.2019-04-05.calendar.csv.gz")
may=pd.read_csv("los.angeles.2019-05-05.calendar.csv.gz")
june=pd.read_csv("los.angeles.2019-06-04.calendar.csv.gz")
july=pd.read_csv("los.angeles.2019-07-08.calendar.csv.gz")
aug=pd.read_csv("los.angeles.2019-08-08.calendar.csv.gz")
sept=pd.read_csv("los.angeles.2019-09-14.calendar.csv.gz")
october=pd.read_csv("los.angeles.2019-10-14.calendar.csv.gz")
nov=pd.read_csv("los.angeles.2019-11-01.calendar.csv.gz")
nov1=pd.read_csv("los.angeles.2019-11-15.calendar.csv.gz")
nov2=pd.read_csv("los.angeles.2019-11-19.calendar.csv.gz")
dec=pd.read_csv("los.angeles.2019-12-05.calendar.csv.gz")

# %%
jan.loc[:,['id','price']]
jan1=jan.loc[jan['id']==109]
jan1
# Out:
#        id        date available    price adjusted_price  minimum_nights  \
# 2394  109  2019-01-12         f  $118.00        $118.00             7.0
# 2395  109  2019-01-13         f  $118.00        $118.00             7.0
# 2396  109  2019-01-14         f  $118.00        $118.00             7.0
# 2397  109  2019-01-15         f  $118.00        $118.00             7.0
# 2398  109  2019-01-16         f  $118.00        $118.00             7.0
# 2399  109  2019-01-17         f  $118.00        $118.00             7.0
# 2400  109  2019-01-18         f  $118.00        $118.00             7.0
# 2401  109  2019-01-19         f  $118.00        $118.00             7.0
# 2402  109  2019-01-20         f  $118.00        $118.00             7.0
# 2403  109  2019-01-21         f  $118.00        $118.00             7.0
# 2404  109  2019-01-22         f  $118.00        $118.00             7.0
# 2405  109  2019-01-23         f  $118.00        $118.00             7.0
# ...

# %%
jan1['price'] = jan1['price'].str.replace(',', '')
jan1['price'] = jan1['price'].str.replace('$', '')
jan1['price'] = jan1['price'].astype(float)
# Out:
# <ipython-input-34-3f3a78d6d98b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan1['price'] = jan1['price'].str.replace(',', '')
# <ipython-input-34-3f3a78d6d98b>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   jan1['price'] = jan1['price'].str.replace('$', '')
# <ipython-input-34-3f3a78d6d98b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
jan1['price'].mean()
# Out:
# 125.88767123287671

# %%
may1=may.loc[may['id']==109]
may1
# Out:
#       id        date available  price adjusted_price  minimum_nights  \
# 120  109  2019-05-05         f  115.0        $115.00            30.0
# 121  109  2019-05-06         f  115.0        $115.00            30.0
# 122  109  2019-05-07         f  115.0        $115.00            30.0
# 123  109  2019-05-08         f  115.0        $115.00            30.0
# 124  109  2019-05-09         f  115.0        $115.00            30.0
# 125  109  2019-05-10         f  115.0        $115.00            30.0
# 126  109  2019-05-11         f  115.0        $115.00            30.0
# 127  109  2019-05-12         f  115.0        $115.00            30.0
# 128  109  2019-05-13         f  115.0        $115.00            30.0
# 129  109  2019-05-14         f  115.0        $115.00            30.0
# 130  109  2019-05-15         f  115.0        $115.00            30.0
# 131  109  2019-05-16         f  115.0        $115.00            30.0
# 132  109  2019-05-17         f  115.0        $115.00            30.0
# ...

# %%
may1['price'].mean()

# %%
jan.rename(columns={'listing_id':'id'},inplace=True)
feb.rename(columns={'listing_id':'id'},inplace=True)
march.rename(columns={'listing_id':'id'},inplace=True)
april.rename(columns={'listing_id':'id'},inplace=True)
may.rename(columns={'listing_id':'id'},inplace=True)
june.rename(columns={'listing_id':'id'},inplace=True)
july.rename(columns={'listing_id':'id'},inplace=True)
aug.rename(columns={'listing_id':'id'},inplace=True)
sept.rename(columns={'listing_id':'id'},inplace=True)
october.rename(columns={'listing_id':'id'},inplace=True)
nov.rename(columns={'listing_id':'id'},inplace=True)
nov1.rename(columns={'listing_id':'id'},inplace=True)
nov2.rename(columns={'listing_id':'id'},inplace=True)
dec.rename(columns={'listing_id':'id'},inplace=True)

# %%
jan_month = jan[jan["date"] <= '2019-02-03']
feb_month=feb[feb["date"]<='2019-03-06']
march_month=march[march["date"]<='2019-04-05']
april_month=april[april["date"]<='2019-05-05']
may_month=may[may["date"]<='2019-06-04']
june_month=june[june["date"]<='2019-07-08']
july_month=july[july["date"]<='2019-08-08']
aug_month = aug[aug["date"] <= '2019-09-14']
sept_month=sept[sept["date"]<='2019-10-14']
october_month=october[october["date"]<='2019-11-01']
nov_month=nov[nov["date"]<='2019-12-05']
dec_month=dec[dec["date"]<='2020-01-03']

# %%
frametest=pd.concat([jan_month,feb_month,march_month,april_month,may_month,june_month,july_month,aug_month,sept_month,october_month,nov_month,dec_month])

# %%
los.angeles.2019-01-11.calendar.csv.gz

# %% [markdown]
# # November Test

# %%
nov_week = nov[nov["date"] <= '2019-11-14']
nov1_week=nov1[nov1["date"] <= '2019-11-19']
nov2_week=nov2[nov2["date"]<='2019-11-30']

# %%
novtest=pd.concat([nov_week,nov1_week,nov2_week])

# %% [markdown]
# # figuring out Axsubplots for x axis intervals

# %% [markdown]
# # Graphs

# %%
frametest_new = frametest.loc[:,['id','date', 'available','price','minimum_nights','maximum_nights']]
frametest_new['busy'] = frametest_new.available.map( lambda x: 0 if x == 't' else 1)
calendar_new2 = frametest_new.groupby('id')['busy'].mean().reset_index()
frametest_date = frametest_new.groupby('date')['busy'].mean().reset_index()
frametest_new['date'] = pd.to_datetime(frametest_new['date'])
plt.figure(figsize=(10, 5))
plt.plot(frametest_date['date'], frametest_date['busy'])
plt.xticks(rotation=90)
plt.title('Airbnb Los Angeles Calendar')
plt.ylabel('% busy')
plt.show();

# %%
nov_new = novtest.loc[:,['id','date', 'available']]
nov_new['busy'] = nov_new.available.map( lambda x: 0 if x == 't' else 1)

nov_date = nov_new.groupby('date')['busy'].mean().reset_index()
nov_new['date'] = pd.to_datetime(nov_new['date'])
plt.figure(figsize=(10, 5))
plt.plot(nov_date['date'], nov_date['busy'])
plt.title('Airbnb Los Angeles Calendar')
plt.ylabel('% busy')
plt.show();

# %%
Fig,ax=plt.subplots()
ax.plot(nov_date['date'], nov_date['busy'])

ax.xaxis.set_major_locator(mdates.DayLocator(interval=2))
plt.xticks(rotation=60)
plt.show()

# %%
nov_new1 = nov_month.loc[:,['id','date', 'available',]]
nov_new1['busy'] = nov_new1.available.map( lambda x: 0 if x == 't' else 1)

nov1_date = nov_new1.groupby('date')['busy'].mean().reset_index()
nov_new1['date'] = pd.to_datetime(nov_new1['date'])
plt.figure(figsize=(10, 5))
plt.plot(nov1_date['date'], nov1_date['busy'])
plt.title('Airbnb Los Angeles Calendar')
plt.ylabel('% busy')
plt.show();

# %%
Fig,ax=plt.subplots()
ax.plot(nov1_date['date'], nov1_date['busy'])

ax.xaxis.set_major_locator(mdates.DayLocator(interval=2))
plt.xticks(rotation=60)
plt.show()

# %%
frametest_new['dayofweek'] = frametest_new.date.dt.day_name()

# %%
cats = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
novtest['date'] = pd.to_datetime(novtest['date'])

# %%
novtest['dayofweek'] = novtest.date.dt.day_name()

# %%
novtest['busy'] = novtest.available.map( lambda x: 0 if x == 't' else 1)

# %%
nov_week1=novtest[['id','date','available','minimum_nights','maximum_nights','busy','dayofweek','price']]

# %%
frametest_new['price'] = frametest_new['price'].str.replace(',', '')
frametest_new['price'] = frametest_new['price'].str.replace('$', '')
frametest_new['price'] = frametest_new['price'].astype(float)
# Out:
# <ipython-input-25-810853287b3b>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   frametest_new['price'] = frametest_new['price'].str.replace('$', '')

# %%
nov_week1['price'] = nov_week1['price'].str.replace(',', '')
nov_week1['price'] = nov_week1['price'].str.replace('$', '')
nov_week1['price'] = nov_week1['price'].astype(float)
# Out:
# <ipython-input-26-fbb600b6d68d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_week1['price'] = nov_week1['price'].str.replace(',', '')
# <ipython-input-26-fbb600b6d68d>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   nov_week1['price'] = nov_week1['price'].str.replace('$', '')
# <ipython-input-26-fbb600b6d68d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Combined November 3 csv DayTrend

# %%
busy_week2 = nov_week1.groupby(['dayofweek']).mean().reindex(cats)
busy_week2.drop(['id','minimum_nights','price','maximum_nights'], axis=1, inplace=True)
busy_week2.plot()
ticks = list(range(0, 7, 1)) # note for self - where on x axis where you want the label to appear
labels = "Mon Tues Weds Thurs Fri Sat Sun".split()
plt.xticks(ticks, labels);

# %%
price_week=frametest_new[['id','date','available','minimum_nights','maximum_nights','busy','dayofweek','price']]

# %%
###price_week1 = price_week.groupby(['dayofweek']).mean().reindex(cats)
###price_week1.drop(['id','minimum_nights','busy','maximum_nights'], axis=1, inplace=True)
###price_week1.plot()
###ticks = list(range(0, 7, 1)) # note for self - where on x axis where you want the label to appear
###labels = "Mon Tues Weds Thurs Fri Sat Sun".split()
###plt.xticks(ticks, labels);

# %% [markdown]
# # Entire Dataset day trend

# %%
price_week2 = price_week.groupby(['dayofweek']).mean().reindex(cats)
price_week2.drop(['id','minimum_nights','price','maximum_nights'], axis=1, inplace=True)
price_week2.plot()
ticks = list(range(0, 7, 1)) # note for self - where on x axis where you want the label to appear
labels = "Mon Tues Weds Thurs Fri Sat Sun".split()
plt.xticks(ticks, labels);

# %%
frametest_new.to_csv("Combined_month_busy.csv.gz",index=False,compression="gzip")
